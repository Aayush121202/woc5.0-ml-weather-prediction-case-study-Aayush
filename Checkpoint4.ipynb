# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
file='C:/Users/patel/Downloads/CarPrice_Assignment.csv'

# %%
import chardet
with open(file, 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': ''}

# %%
df=pd.read_csv(file, encoding ='ascii')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
array=df['horsepower'].to_numpy()

# %%
plt.hist(array,edgecolor="k")
plt.xlabel("Horsepower")
plt.show()

# %%
sb.kdeplot(df.horsepower,shade=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Density'>

# %%
sb.kdeplot(df.horsepower,df.enginesize,shade=False)
# Out:
# C:\Users\patel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='horsepower', ylabel='enginesize'>

# %%
sb.histplot(df.horsepower,bins=20)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='Count'>

# %%
sb.histplot(x=df.horsepower,y=df.enginesize,cbar=True)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='enginesize'>

# %%
sb.ecdfplot(df.enginesize)
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='Proportion'>

# %%
plt.figure(figsize=(25,25))
sb.boxplot(x=df.enginesize,y=df.horsepower)
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='horsepower'>

# %%
sb.violinplot(x=df.enginesize)
# Out:
# <AxesSubplot:xlabel='enginesize'>

# %%
sb.violinplot(x=df.price)
sb.swarmplot(x=df.price,color="k")
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sb.scatterplot(x=df.horsepower,y=df.price)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
sb.lineplot(x=df.horsepower,y=df.price)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
sb.regplot(x=df.citympg,y=df.highwaympg)
# Out:
# <AxesSubplot:xlabel='citympg', ylabel='highwaympg'>

# %%
df.corr()
# Out:
#                     car_ID  symboling  wheelbase  carlength  carwidth  \
# car_ID            1.000000  -0.151621   0.129729   0.170636  0.052387
# symboling        -0.151621   1.000000  -0.531954  -0.357612 -0.232919
# wheelbase         0.129729  -0.531954   1.000000   0.874587  0.795144
# carlength         0.170636  -0.357612   0.874587   1.000000  0.841118
# carwidth          0.052387  -0.232919   0.795144   0.841118  1.000000
# carheight         0.255960  -0.541038   0.589435   0.491029  0.279210
# curbweight        0.071962  -0.227691   0.776386   0.877728  0.867032
# enginesize       -0.033930  -0.105790   0.569329   0.683360  0.735433
# boreratio         0.260064  -0.130051   0.488750   0.606454  0.559150
# stroke           -0.160824  -0.008735   0.160959   0.129533  0.182942
# compressionratio  0.150276  -0.178515   0.249786   0.158414  0.181129
# horsepower       -0.015006   0.070873   0.353294   0.552623  0.640732
# ...

# %%
plt.figure(figsize=(10,10))
sb.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sb.clustermap(df.corr())

# %%
plt.figure(figsize=(20,20))
sb.barplot(x=df.horsepower,y=df.price,ci=None)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='price'>

# %%
plt.figure(figsize=(20,20))
sb.countplot(x=df.horsepower)
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='count'>
